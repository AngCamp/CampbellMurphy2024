# %% [markdown]
# The tag "2023_Q3_Findling_Hubert_et_al" should be for this biorvx paper on the bayesion prior information where the task prior was altered: [Findling et al., (2023)](https://www.biorxiv.org/content/10.1101/2023.07.04.547684v4).

# %% [markdown]
# Link to loading raw LFP data: https://int-brain-lab.github.io/iblenv/notebooks_external/loading_ephys_data.html <br>
# The dataset is also available through dandi at this URL: https://dandiarchive.org/dandiset/000409?search=IBL&pos=1
#
#
# IBL Tutorials are available here: https://docs.google.com/presentation/d/e/2PACX-1vSS5zPrwk9ntzUV9LiS-HNusCXsqB-sYwvwjTx03RENbohAJf0ujzjjffiHqtvn1PV-AwtcWC2LqgxA/pub?delayms=60000&loop=false&start=false&slide=id.g2041f60a190_0_58

# %%
import os
import subprocess 
import numpy as np
import pandas as pd
from scipy import io, signal, stats
from scipy.signal import lfilter
#from fitter import Fitter, get_common_distributions, get_distributions
import scipy.ndimage
from scipy.ndimage import gaussian_filter
from scipy.ndimage import gaussian_filter1d
from scipy import interpolate
import matplotlib.pyplot as plt
# for ripple detection
import ripple_detection
from ripple_detection import filter_ripple_band
import ripple_detection.simulate as ripsim # for making our time vectors
import piso #can be difficult to install, https://piso.readthedocs.io/en/latest/
from tqdm import tqdm
from iblatlas.atlas import AllenAtlas
from iblatlas.regions import BrainRegions
from one.api import ONE
import spikeglx
from brainbox.io.one import load_channel_locations
from brainbox.io.spikeglx import Streamer
from neurodsp.voltage import destripe_lfp

#THIS CODE WORKS THIS CODE LOOPS THROUGH THE SESSIONS AND DOWNLOADS THE DATA, WE NEED TO ADD THE RIPPLE DETECTION CODE TO REMOVE THE DATA AFTER 
from neurodsp.voltage import destripe_lfp
from ibllib.plots import Density
import time # for debugging

from multiprocessing import Pool
#functions 

# subprocess is a default module
def call_bash_function(bash_command = ""):
    #example bash comand:
    #bash_command = "source /path/to/your/bash_script.sh && your_bash_function"
    process = subprocess.Popen(bash_command, stdout=subprocess.PIPE, shell=True)
    output, error = process.communicate()

    if process.returncode == 0:
        print("Bash function executed successfully.")
        print("Output:", output.decode('utf-8'))
    else:
        print("Error:", error.decode('utf-8'))

# Assuming you have your signal_array, b, and a defined as before
def finitimpresp_filter_for_LFP(LFP_array, samplingfreq, lowcut = 1, highcut = 250,
                    filter_order = 101):
    
    nyquist = 0.5 * samplingfreq

    # Design the FIR bandpass filter using scipy.signal.firwin
    fir_coeff = signal.firwin(filter_order, [lowcut / nyquist, highcut / nyquist],
                              pass_zero=False, fs=samplingfreq)

    # Apply the FIR filter to your signal_array
    #filtered_signal = signal.convolve(LFP_array, fir_coeff, mode='same', method='auto')
    filtered_signal = signal.lfilter(fir_coeff, 1.0, LFP_array, axis=0)
    return(filtered_signal)


def event_boundary_detector(time, five_to_fourty_band_power_df, envelope=True, minimum_duration = 0.02, maximum_duration = 0.4,
                       threshold_sd=2.5, envelope_threshold_sd=1):
    """
    Power threshold event detector, includes an envelope as well if wanted
    
    Originally for detecting sharp waves in the striatum radiatum, takes in power signal from 
    
    From Fernández-Ruiz, A., Oliva, A., Fermino de Oliveira, E., Rocha-Almeida, F., Tingley, D., 
    & Buzsáki, G. (2019). Long-duration hippocampal sharp wave ripples improve memory. Science, 364(6445), 1082-1086.
    
    
    Sharp waves were detected separately using LFP from a CA1 str. radiatum channel, filtered with band-pass filter boundaries
   (5-40 Hz). LFP events of a minimum duration of 20 ms and maximum 400 ms exceeding 2.5 SD of the
   background signal were included as candidate SPWs. Only if a SPW was simultaneously detected with
   a ripple, a CA1 SPW-R event was retained for further analysis. SPW-R bursts were classified when more
   than one event was detected in a 400 ms time window.
    
    """
    
    # make df to fill
    row_of_info =  {
        'start_time': [],
        'end_time': [],
        'duration': [],
        }

    #sharp_wave_events_df = pd.DataFrame()
    #scored_wave_power = stats.zscore(five_to_fourty_band_df)
    
    # compute our power threshold
    #wave_band_sd_thresh = np.std(five_to_fourty_band_df)*threshold_sd
    five_to_fourty_band_power_df = stats.zscore(five_to_fourty_band_power_df)
    past_thresh = five_to_fourty_band_power_df>=threshold_sd
    
    # now we expand the sections that are past thresh up to the points that 
    # are past the envelope thresh, so not all sections above envelope thresh are true
    # but those sections which alse contain a region past the detection threshold are included
    def expand_sections(z_scores, boolean_array, thresh):
        # Find indices where boolean_array is True
        true_indices = np.where(boolean_array)[0]

        # Initialize an array to keep track of expanded sections
        expanded_sections = np.zeros_like(z_scores, dtype=bool)

        # Iterate over true_indices and expand sections
        for index in true_indices:
            # Find the start and end of the current section
            start = index
            end = index

            # Expand section to the left (while meeting conditions)
            while start > 0 and z_scores[start - 1] >  thresh:
                start -= 1

            # Expand section to the right (while meeting conditions)
            while end < len(z_scores) - 1 and z_scores[end + 1] >  thresh:
                end += 1

            # Check if the expanded section contains a point above envelope_threshold_sd in z_scores
            if any(z_scores[start:end + 1] >  thresh):
                expanded_sections[start:end + 1] = True

        # Update the boolean_array based on expanded_sections
        boolean_array = boolean_array | expanded_sections

        return boolean_array
    
    if envelope==True:
        past_thresh = expand_sections(z_scores=five_to_fourty_band_power_df,
                                  boolean_array= past_thresh,
                                  thresh = envelope_threshold_sd)
    
    
    # Find the indices where consecutive True values start
    starts = np.where(past_thresh & ~np.roll(past_thresh, 1))[0]
    row_of_info['start_time'] = time[starts]
    # Find the indices where consecutive True values end
    ends = np.where(past_thresh & ~np.roll(past_thresh, -1))[0]
    row_of_info['end_time'] = time[ends]
    
    row_of_info['duration'] = [row_of_info['end_time'][i]-row_of_info['start_time'][i] for i in range(0,len(row_of_info['start_time']))]
    
    #turn the dictionary into adataframe
    sharp_wave_events_df = pd.DataFrame(row_of_info)
    
    # filter for the duration range we want
    in_duration_range = (sharp_wave_events_df.duration>minimum_duration)&(sharp_wave_events_df.duration<maximum_duration)
    sharp_wave_events_df = sharp_wave_events_df[in_duration_range]
    
    return sharp_wave_events_df

def event_boundary_times(time, past_thresh):
    """
    finds the times of a vector of true statements and returns values from another
    array representing the times
    """
    # Find the indices where consecutive True values start
    starts = np.where(past_thresh & ~np.roll(past_thresh, 1))[0]
    row_of_info['start_time'] = time[starts]
    # Find the indices where consecutive True values end
    ends = np.where(past_thresh & ~np.roll(past_thresh, -1))[0]
    row_of_info['end_time'] = time[ends]
    
    row_of_info['duration'] = [row_of_info['end_time'][i]-row_of_info['start_time'][i] for i in range(0,len(row_of_info['start_time']))]
    
    #turn the dictionary into adataframe
    events_df = pd.DataFrame(row_of_info)
      
    return events_df

def peaks_in_events(events, time_values, signal_values):
    # looks for the peask in the lfp signal, value of zscored raw lfp peak and returns time of peak
    signal_values_zscore = stats.zscore(signal_values)
    max_values = []
    max_lfp_zscore_values = []
    peak_times = []
    for start, end in zip(events['start_time'], events['end_time']):
        window_idx = (time_values >= start) & (time_values <= end)
        ripplesignal = signal_values[window_idx]
        ripple_lfp_zscore_signal = signal_values_zscore[window_idx]
        maxpoint = np.argmax(ripplesignal)
        max_values.append(ripplesignal[maxpoint])
        max_lfp_zscore_values.append(ripple_lfp_zscore_signal[maxpoint])
        rippletimepoints = time_values[window_idx]
        peak_times.append(rippletimepoints[maxpoint])
    return np.array(max_values), np.array(max_lfp_zscore_values),  np.array(peak_times)

def resample_signal(signal, times, new_rate):
    """
    Resample a 2D signal array to a new sampling rate.

    Parameters:
    signal (np.array): 2D array where each column is a source and each row is a time point.
    times (np.array): 1D array of times corresponding to the rows of the signal array.
    new_rate (float): The new sampling rate in Hz.

    Returns:
    new_signal (np.array): The resampled signal array.
    new_times (np.array): The times corresponding to the rows of the new signal array.
    """
    nsamples_new = int(len(times) * new_rate / (len(times) / times[-1]))
    new_times = np.linspace(times[0], times[-1], nsamples_new)
    new_signal = np.zeros((signal.shape[0], nsamples_new))

    for i in range(signal.shape[0]):
        interp_func = interpolate.interp1d(times, signal[i,:], bounds_error=False, fill_value="extrapolate")
        new_signal[i,:] = interp_func(new_times)

    return new_signal, new_times

def gamma_band_1500hzsig_filter(interpolated_1500hz_signal, 
                                filters_path = ["/home/acampbell/Stienmetz2019Reanalyzed/ExtractingSWRs/PowerBandFilters/Gamma_Band_withlowpass_Filter/lowpass_prefilter.npy",
                                                "/home/acampbell/Stienmetz2019Reanalyzed/ExtractingSWRs/PowerBandFilters/Gamma_Band_withlowpass_Filter/gamma_band_filter.npy"]):
    """
    Takes in a signal interpolated to 1500 Hz and returns the signal filtered in the gamma band, using filters designed for 1500 Hz.
    
    Parameters
    ----------
    interpolated_1500hz_signal : array_like
        The signal interpolated to 1500 Hz.
    filters_path : list of str
        The path to the filters to be used for filtering the signal.
        
    Returns
    -------
    bandpassed_signal : array_like
        The filtered signal.
        
    Notes:    
    How filters were made:
        # Define the order of the low-pass filter
        numtaps = 101

        # Define the cutoff frequency (in Hz) for the low-pass filter
        cutoff_hz = 625.0
        # Create the low-pass filter
        low_pass_taps = firwin(numtaps, cutoff_hz/(0.5*1500), window='hamming')
    
        # Now create your bandpass filter
        bandpass_taps = make_bandpass_filter(sampling_frequency=1500, BAND_OF_INTEREST = [20, 80],
                                TRANSITION_BAND = 10, ORDER = 250)
                                
    
    """
    # Create the low-pass filter
    low_pass_taps = np.load(filters_path[0])

    # Apply the low-pass filter to your signal
    low_passed_signal = lfilter(low_pass_taps, 1.0, interpolated_1500hz_signal)

    # Now create your bandpass filter
    bandpass_taps = np.load(filters_path[1])

    # Apply the bandpass filter to the low-passed signal
    bandpassed_signal = lfilter(bandpass_taps, 1.0, low_passed_signal)
    
    return bandpassed_signal


from one.api import ONE
ONE.setup(base_url='https://openalyx.internationalbrainlab.org', silent=True)
one = ONE(password='international')
# Parameters, (input output file paths and thresholds)

gamma_filters_path = ["/home/acampbell/Stienmetz2019Reanalyzed/ExtractingSWRs/PowerBandFilters/Gamma_Band_withlowpass_Filter/lowpass_prefilter.npy",
                                                "/home/acampbell/Stienmetz2019Reanalyzed/ExtractingSWRs/PowerBandFilters/Gamma_Band_withlowpass_Filter/gamma_band_filter.npy"]

# cache location
oneapi_cache_dir = '/space/scratch/IBL_data_cache'# path to where the cache for the allensdk is (wehre the lfp is going)
output_dir = '/space/scratch/IBL_swr_data'
swr_output_dir = 'IBL_swr_test' # directory specifying the output

# THRESHOLDS
gamma_event_thresh = 3 # zscore threshold for gamma events
ripple_band_threshold = 2 # note this defines the threshold for envelopes, from these events identify ones with peaks that pass a peak-power threshold as well
movement_artifact_ripple_band_threshold = 2

# see the notebook SearchingForSubsetforTesting.ipynb to see how this list was generated, this will be our testing list
# first fourteen are from Fingling et al., (2023) via..
# one.load_cache(tag = '2022_Q2_IBL_et_al_RepeatedSite',)
# sessions_rep_sites = one.search()
# then clear the cache...

testing_list = ['0c828385-6dd6-4842-a702-c5075f5f5e81','111c1762-7908-47e0-9f40-2f2ee55b6505','8a3a0197-b40a-449f-be55-c00b23253bbf','1a507308-c63a-4e02-8f32-3239a07dc578','1a507308-c63a-4e02-8f32-3239a07dc578','73918ae1-e4fd-4c18-b132-00cb555b1ad2',
 '73918ae1-e4fd-4c18-b132-00cb555b1ad2','09b2c4d1-058d-4c84-9fd4-97530f85baf6','5339812f-8b91-40ba-9d8f-a559563cc46b','034e726f-b35f-41e0-8d6c-a22cc32391fb','83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4','83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4','931a70ae-90ee-448e-bedb-9d41f3eda647',
 'd2832a38-27f6-452d-91d6-af72d794136c','dda5fc59-f09a-4256-9fb5-66c67667a466','e2b845a1-e313-4a08-bc61-a5f662ed295e','a4a74102-2af5-45dc-9e41-ef7f5aed88be','572a95d1-39ca-42e1-8424-5c9ffcb2df87','781b35fd-e1f0-4d14-b2bb-95b7263082bb',
 'b01df337-2d31-4bcc-a1fe-7112afd50c50','e535fb62-e245-4a48-b119-88ce62a6fe67','614e1937-4b24-4ad3-9055-c8253d089919','7f6b86f9-879a-4ea2-8531-294a221af5d0','824cf03d-4012-4ab1-b499-c83a92c5589e','4b00df29-3769-43be-bb40-128b1cba6d35','ff96bfe1-d925-4553-94b5-bf8297adf259']

#dont_wipe_these_sessions =['0c828385-6dd6-4842-a702-c5075f5f5e81']
# testing_list = np.load('testing_list.npy')

dont_wipe_these_sessions =[]

# load in the brain atlas and the brain region object for working with the ccf and ABI region id's in channels objects
ba = AllenAtlas()
br = BrainRegions() # br is also an attribute of ba so could to br = ba.regions

#Searching for datasets
brain_acronym = 'CA1'
# query sessions endpoint
#sessions, sess_details = one.search(atlas_acronym=brain_acronym, query_type='remote', details=True)

# query insertions endpoint
#insertions = one.search_insertions(atlas_acronym=brain_acronym)
#session_list = [x for x in sessions] # when we need to loop through all the sessions
session_list = testing_list
dont_wipe_these_sessions =[]

swr_output_dir_path = os.path.join(output_dir, swr_output_dir)
os.makedirs(swr_output_dir, exist_ok=True)
sessions_without_ca1 = np.array([])
#from multiprocessing import Pool

def process_session(session_id):
    """
    Process used to process a single session insode a multiprocessing call.
    Remember to set up the brain atlas first:
       ba = AllenAtlas()
       br = BrainRegions()
       
    The input is the eid for the IBL experiment (session) you want to process.
    """
    
    #one = ONE(password='international') # restarting one for this loop
    eid = session_id # just to keep the naming similar to the IBL example scripts, bit silly but helps to write the code
    probelist, probenames = one.eid2pid(eid) # probe_id is pid in the IBL tutorials
    
    print(f'Probe IDs: {probelist}, Probe names: {probenames}')
    
    band = 'lf' # either 'ap','lf'
    
    # Create subfolder for session, will contain all csvs for events detected and .npy of ca1 channels and control channels 
    session_subfolder = "swrs_session_" + str(session_id)
    session_subfolder = os.path.join(swr_output_dir_path, session_subfolder)
    os.makedirs(session_subfolder, exist_ok=True)
    
    
    #for probe_id in pid:
    for this_probe in range(len(probelist)):
        probe_name = probenames[this_probe]
        probe_id = probelist[this_probe]
        print(probe_id)
        # first check if this probe even has CA1 channels on it, no need to process if not
        print("getting channels data")
        collectionname = f'alf/{probe_name}/pykilosort'
        channels = one.load_object(eid, 'channels', collection=collectionname)
        channels.allen2017_25um_acronym = br.id2acronym( channels['brainLocationIds_ccf_2017'] )
        
        regions_on_probe = np.unique(channels.allen2017_25um_acronym)
        if 'CA1' not in regions_on_probe:
            print(f'No CA1 channels on probe {probe_id}, skipping...')
            continue
                
        # Find the relevant datasets and download them
        dsets = one.list_datasets(eid, collection=f'raw_ephys_data/{probe_name}', filename='*.lf.*')
        print(type(dsets))
        print(len(dsets))
        data_files, _ = one.load_datasets(eid, dsets, download_only=False)
        bin_file = next(df for df in data_files if df.suffix == '.cbin')

        # Use spikeglx reader to read in the whole raw data
        print("sr = spikeglx.Reader(bin_file)")
        start_time = time.time()
        sr = spikeglx.Reader(bin_file)
        print(f"done, time elapsed: {time.time() - start_time}")
        # Important: remove sync channel from raw data, and transpose
        print("raw = sr[:, :-sr.nsync].T")
        start_time = time.time()
        raw = sr[:, :-sr.nsync].T
        print(f"done, time elapsed: {time.time() - start_time}")
        # Reminder : If not done before, remove first the sync channel from raw data
        # Apply destriping algorithm to data
        
        # code to be used in final version but in the meantime we will load in the destriped data from the saved folder just to save time
        print("destriped = destripe(raw, fs=sr.fs)")
        start_time = time.time()
        destriped = destripe_lfp(raw, fs=sr.fs)
        del raw
        print(f"destripped shape : {destriped.shape}")
        print(f"done, time elapsed: {time.time() - start_time}")
        
        # just for debugging
        # np.load function will load the .npz file
        #data = np.load("/space/scratch/test_destripe_save/debugging_destriped_save.npz")

        # You can access your saved array with the keyword you used while saving
        #destriped = data['destriped']
        print("destriped loaded...")
        del raw
        #del data
        
        #GETTING THE CA1 CHANNEL WITH PEAK RIPPLE POWER AND CONTROL CHANNELS
        # get hippocampal channel
        ca1_chans = channels.rawInd[channels.allen2017_25um_acronym == 'CA1']
        
        # select ca1 channels 
        lfp_ca1  = destriped[ca1_chans,:]
        
        # get the timestamps for this lfp recording
        #2 columns file containing time synchronisation information for the AP binary file: 
        # sample index in the first column and session time in the second column. Note that sample indices may not be integers
        lfp_time_timestamps_path = one.list_datasets(eid, collection=f'raw_ephys_data/{probe_name}', filename='*timestamps.npy')
        lfp_time_timestamps, _ = one.load_datasets(eid, lfp_time_timestamps_path, download_only=False)

        # Divide the first column by 12
        lfp_time_timestamps = lfp_time_timestamps[1]

        adjusted_samples = lfp_time_timestamps[:, 0] / 12

        # Create an array of sample numbers for your signal
        sample_numbers = np.arange(destriped.shape[1])

        # Interpolate to get lfp_time_index_og
        lfp_time_index_og = np.interp(sample_numbers, adjusted_samples, lfp_time_timestamps[:, 1])
        lfp_ca1, lfp_time_index = resample_signal(lfp_ca1, lfp_time_index_og, 1500.0) # note the original samplig rate is infered from the times object
        lfp_ca1 = lfp_ca1.T # transpose to get the right shape for the rest of the code
        
        lfp_ca1_ripppleband = filter_ripple_band(lfp_ca1)
        highest_rip_power = np.abs(signal.hilbert(lfp_ca1_ripppleband))**2
        highest_rip_power = highest_rip_power.max(axis=0)
           
        # ideally we would store the channels for later use, but each lfp has it's own time and sampling rate that it goes through
        # note channels do not have unique ids in the IBL unlike in the allen institute so instead we use their rawInd value
        this_chan_id = "channelsrawInd_"+str(ca1_chans[highest_rip_power.argmax()]) # for naming the file later, this way we know what object its from so we dont go looking for an id
        peakrippleband = lfp_ca1_ripppleband[:,highest_rip_power.argmax()]
        
        peakripple_chan_raw_lfp = lfp_ca1[:,highest_rip_power.argmax()]
        del lfp_ca1 # clear up some memory
        # filter it to gamma band
        gamma_band_ca1 = gamma_band_1500hzsig_filter(peakripple_chan_raw_lfp, filters_path = gamma_filters_path)
        
        # get the control channels here, store their index so you can name them later
        not_a_ca1_chan = np.logical_not(np.isin(channels.allen2017_25um_acronym,[ "CA3", "CA2", "CA1", "HPF", "EC", "DG"]))

        # Find the indices of the blocks of False i.e. the channels that are ca1
        take_two = np.random.choice(channels.rawInd [not_a_ca1_chan], 2, replace=False)
        outof_hp_chans_lfp = []
        
        # making list to hold the arrays of the control channels
        for channel_outside_hp in take_two:
            lfp_control = destriped[channel_outside_hp,:]
            interp_func = interpolate.interp1d(lfp_time_index_og, lfp_control, bounds_error=False, fill_value="extrapolate")
            lfp_control = interp_func(lfp_time_index)
            lfp_control = lfp_control.T # transpose to get the right shape for the rest of the code
            
            
            outof_hp_chans_lfp.append(lfp_control[:,None])
            # clean it up
            del lfp_control

        # write our lfp to file
        np.savez(os.path.join(session_subfolder, f"probe_{probe_id}_channel_{this_chan_id}_lfp_ca1_peakripplepower.npz"), lfp_ca1 = peakripple_chan_raw_lfp)
        np.savez(os.path.join(session_subfolder, f"probe_{probe_id}_channel_{this_chan_id}_lfp_time_index_1500hz.npz"), lfp_time_index = lfp_time_index)
        for i in range(2):
            channel_outside_hp = take_two[i]
            channel_outside_hp = "channelsrawInd_"+ str(channel_outside_hp)
            np.savez(os.path.join(session_subfolder, f"probe_{probe_id}_channel_{channel_outside_hp}_lfp_control_channel.npz"), lfp_control_channel = outof_hp_chans_lfp[i])
        # delete the dataframes we don't need to clear up some memory
        del destriped
        
        # FILTERING FOR EVENTS IN THE PROCESSED CHANNELS, WRITING TO FILE
        
        # ripples
        # make fake speed variable, we can use this for now and fix it later              
        dummy_speed = np.zeros_like(peakrippleband)
        print("Detecting Putative Ripples")
        # we add a dimension to peakrippleband because the ripple detector needs it
        Karlsson_ripple_times = ripple_detection.Karlsson_ripple_detector(
            time = lfp_time_index, 
            zscore_threshold= ripple_band_threshold,
            filtered_lfps = peakrippleband[:,None], 
            speed = dummy_speed, 
            sampling_frequency = 1500.0
        )
        # there is no need for this criteria (Karlsson_ripple_times.duration>0.015)&(Karlsson_ripple_times.duration<0.25)
        # because they are already filtered for minimum duration
        # but we need to do it for maximum duration
        Karlsson_ripple_times = Karlsson_ripple_times[Karlsson_ripple_times.duration<0.25]
        print("Done")
        # adds some stuff we want to the file
        
        # ripple band power
        peakrippleband_power = np.abs(signal.hilbert(peakrippleband))**2
        Karlsson_ripple_times['Peak_Amp_RipBandPower'], Karlsson_ripple_times['Peak_Amp_RipBandPower_zscore'],  Karlsson_ripple_times['Peak_time'] = peaks_in_events(events=Karlsson_ripple_times, 
                                                                                                                           time_values=lfp_time_index, 
                                                                                                                           signal_values=peakrippleband_power)
        
        csv_filename = f"probe_{probe_id}_channel_{this_chan_id}_karlsson_detector_events.csv"
        csv_path = os.path.join(session_subfolder, csv_filename)
        Karlsson_ripple_times.to_csv(csv_path, index=True)
        print("Writing to file.")
        print("Detecting gamma events.")
        # gamma events
        # gamma power
        # compute this later, I will have a seperate script called SWR filtering which will do this
        #gamma_band = finitimpresp_filter_for_LFP(lfp_ca1[:,lfp_ca1_chans == this_chan_id], samplingfreq =  1500.0, lowcut = 20, highcut = 80)
        gamma_power = np.abs(signal.hilbert(gamma_band_ca1))**2
        gamma_times = event_boundary_detector(time = lfp_time_index, threshold_sd = gamma_event_thresh, envelope=False, 
                                      minimum_duration = 0.015, maximum_duration = float('inf'),
                                  five_to_fourty_band_power_df = gamma_power)
        print("Done")
        csv_filename = f"probe_{probe_id}_channel_{this_chan_id}_gamma_band_events.csv"
        csv_path = os.path.join(session_subfolder, csv_filename)
        gamma_times.to_csv(csv_path, index=True)
        
        # movement artifact detection
        for i in [0,1]:
            # process control channel ripple times
            ripple_band_control = outof_hp_chans_lfp[i]
            ripple_band_control = filter_ripple_band(ripple_band_control)
            rip_power_controlchan = np.abs(signal.hilbert(ripple_band_control))**2
            movement_controls = ripple_detection.Karlsson_ripple_detector(
                time = lfp_time_index, # if this doesnt work try adding .reshape(-1)
                filtered_lfps = rip_power_controlchan, # indexing [:,None] is not needed here, rip_power_controlchan is already 2d (nsamples, 1)
                speed = dummy_speed, # if this doesnt work try adding .reshape(-1)
                zscore_threshold= movement_artifact_ripple_band_threshold,
                sampling_frequency = 1500.0
            )
            
            # write to file name
            channel_outside_hp = take_two[i]
            channel_outside_hp = "channelsrawInd_"+ str(channel_outside_hp) # no cjannel id in IBL dataset, so this will do instead
            csv_filename = f"probe_{probe_id}_channel_{channel_outside_hp}_movement_artifacts.csv"
            csv_path = os.path.join(session_subfolder, csv_filename)
            movement_controls.to_csv(csv_path, index=True)
            print("Done Probe id " + str(probe_id))

# %%
with Pool(3) as p:
    p.map(process_session, session_list[0:3])
# Out:
# Probe IDs: ['3d3d5a5e-df26-43ee-80b6-2d72d85668a5'], Probe names: ['probe00']Probe IDs: ['27bac116-ea57-4512-ad35-714a62d259cd', 'eebcaf65-7fa4-4118-869d-a084e84530e2'], Probe names: ['probe00', 'probe01']Probe IDs: ['f9d8aacd-b2a0-49f2-bd71-c2f5aadcfdd1', 'a94a0023-d461-49fa-8cc6-032237039c27'], Probe names: ['probe00', 'probe01']
#
#
# 3d3d5a5e-df26-43ee-80b6-2d72d85668a5f9d8aacd-b2a0-49f2-bd71-c2f5aadcfdd1
# 27bac116-ea57-4512-ad35-714a62d259cd
# getting channels data
# getting channels data
# getting channels data
#
# <class 'list'>
# 3
#   0%|          | 0/11.0 [00:00<?, ?it/s]
# <class 'list'><class 'list'>
#
# 33
# 100%|██████████| 11/11.0 [00:04<00:00,  2.72it/s]
# 100%|██████████| 12/12.0 [00:04<00:00,  2.99it/s]
# sr = spikeglx.Reader(bin_file)sr = spikeglx.Reader(bin_file)
#
# done, time elapsed: 0.0041959285736083984
# done, time elapsed: 0.004438877105712891raw = sr[:, :-sr.nsync].T
#
# raw = sr[:, :-sr.nsync].T
# 100%|██████████| 13/13.0 [00:06<00:00,  1.92it/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004578113555908203
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 38.28423023223877
# destriped = destripe(raw, fs=sr.fs)
# done, time elapsed: 38.33224081993103
# destriped = destripe(raw, fs=sr.fs)
# done, time elapsed: 44.342910289764404
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11397043)
# done, time elapsed: 1093.714700460434
# destriped loaded...
# destripped shape : (384, 13630721)
# done, time elapsed: 1318.960252046585
# destriped loaded...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 2
#       1 with Pool(3) as p:
# ----> 2     p.map(process_session, session_list[0:3])
#
# File ~/miniconda3/envs/ONE_ibl_env/lib/python3.10/multiprocessing/pool.py:364, in Pool.map(self, func, iterable, chunksize)
#     359 def map(self, func, iterable, chunksize=None):
#     360     '''
#     361     Apply `func` to each element in `iterable`, collecting the results
#     362     in a list that is returned.
#     363     '''
# --> 364     return self._map_async(func, iterable, mapstar, chunksize).get()
#
# File ~/miniconda3/envs/ONE_ibl_env/lib/python3.10/multiprocessing/pool.py:765, in ApplyResult.get(self, timeout)
#     764 def get(self, timeout=None):
# --> 765     self.wait(timeout)
#     766     if not self.ready():
#     767         raise TimeoutError
#
# File ~/miniconda3/envs/ONE_ibl_env/lib/python3.10/multiprocessing/pool.py:762, in ApplyResult.wait(self, timeout)
#     761 def wait(self, timeout=None):
# --> 762     self._event.wait(timeout)
#
# File ~/miniconda3/envs/ONE_ibl_env/lib/python3.10/threading.py:600, in Event.wait(self, timeout)
#     598 signaled = self._flag
#     599 if not signaled:
# --> 600     signaled = self._cond.wait(timeout)
#     601 return signaled
#
# File ~/miniconda3/envs/ONE_ibl_env/lib/python3.10/threading.py:320, in Condition.wait(self, timeout)
#     318 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     319     if timeout is None:
# --> 320         waiter.acquire()
#     321         gotit = True
#     322     else:
#
# KeyboardInterrupt:

# %%
with Pool(1) as p:
    p.map(process_session, session_list[0:1])
# Out:
# Probe: ['3d3d5a5e-df26-43ee-80b6-2d72d85668a5'], Probe name: ['probe00']Probe: ['27bac116-ea57-4512-ad35-714a62d259cd', 'eebcaf65-7fa4-4118-869d-a084e84530e2'], Probe name: ['probe00', 'probe01']
#
# probe00probe00
#
# <class 'list'><class 'list'>
#
# 33
#   0%|          | 0/12.0 [00:00<?, ?it/s]
# 100%|██████████| 11/11.0 [00:03<00:00,  2.83it/s]
#  92%|█████████▏| 11/12.0 [00:03<00:00,  2.82it/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004862308502197266
# raw = sr[:, :-sr.nsync].T
# 100%|██████████| 12/12.0 [00:03<00:00,  3.03it/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004615068435668945
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 38.394672870635986
# destriped = destripe(raw, fs=sr.fs)
# done, time elapsed: 40.88908553123474
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11397043)
# done, time elapsed: 1171.3350939750671
# destriped loaded...
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/.nfs00000000000cdb7500000291’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/.nfs00000000000cdb7500000291’: Device or resource busy
# destripped shape : (384, 11471112)
# done, time elapsed: 2764.3184065818787
# destriped loaded...
# probe01
# <class 'list'>
# 3
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.cbin: 100%|██████████| 2.87G/2.87G [00:29<00:00, 96.5MB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.ch: 100%|██████████| 132k/132k [00:00<00:00, 390kB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.meta: 100%|██████████| 14.0k/14.0k [00:00<00:00, 68.4kB/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.0060427188873291016
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 39.91889214515686
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11471128)
# done, time elapsed: 1089.7704684734344
# destriped loaded...
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb8700000292’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cdb7200000293’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb8700000292’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cdb7200000293’: Device or resource busy

# %%
#del sr 
one = ONE(password='international')
if (session_id not in dont_wipe_these_sessions):
    session_path = str(one.eid2path(eid))
    del one
    # create the full path to the directory you want to delete
    # create the full path to the directory you want to delete
    dir_to_delete = f"{session_path}/raw_ephys_data"
    print

    # call the bash command
    remove_from_path_command = "find " + dir_to_delete + " -type d -exec rm -rf {} +"
    subprocess.run(remove_from_path_command, shell=True)
    
    # Then, remove the directory itself
    remove_dir_command = "find " + session_path + " -type d -name 'raw_ephys_data' -exec rm -r {} +"
    subprocess.run(remove_dir_command, shell=True)
# Out:
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy

# %%
# probe id and experiment id
for session_id in session_list[0:2]:
    one = ONE(password='international') # restarting one for this loop
    eid = session_id # just to keep the naming similar to the IBL example scripts, bit silly but helps to write the code
    pid, probename = one.eid2pid(eid)
    print(f'Probe: {pid}, Probe name: {probename}')
    
    band = 'lf' # either 'ap','lf'
    #for this_probe in pid:
    for this_probe in probename:
        print(this_probe)
        # Find the relevant datasets and download them
        dsets = one.list_datasets(eid, collection=f'raw_ephys_data/{this_probe}', filename='*.lf.*')
        print(type(dsets))
        print(len(dsets))
        data_files, _ = one.load_datasets(eid, dsets, download_only=False)
        bin_file = next(df for df in data_files if df.suffix == '.cbin')

        # Use spikeglx reader to read in the whole raw data
        print("sr = spikeglx.Reader(bin_file)")
        start_time = time.time()
        sr = spikeglx.Reader(bin_file)
        print(f"done, time elapsed: {time.time() - start_time}")
        # Important: remove sync channel from raw data, and transpose
        print("raw = sr[:, :-sr.nsync].T")
        start_time = time.time()
        raw = sr[:, :-sr.nsync].T
        print(f"done, time elapsed: {time.time() - start_time}")
        # Reminder : If not done before, remove first the sync channel from raw data
        # Apply destriping algorithm to data
        
        # code to be used in final version but in the meantime we will load in the destriped data from the saved folder just to save time
        print("destriped = destripe(raw, fs=sr.fs)")
        start_time = time.time()
        destriped = destripe(raw, fs=sr.fs)
        print(f"destripped shape : {destriped.shape}")
        print(f"done, time elapsed: {time.time() - start_time}")
        
        # just for debugging
        # np.load function will load the .npz file
        #data = np.load("/space/scratch/test_destripe_save/debugging_destriped_save.npz")

        # You can access your saved array with the keyword you used while saving
        #destriped = data['destriped']
        del raw
        #del data
        print("destriped loaded...")
        
    del sr
    if (session_id not in dont_wipe_these_sessions):
        session_path = str(one.eid2path(eid))
        del one
        # create the full path to the directory you want to delete
        # create the full path to the directory you want to delete
        dir_to_delete = f"{session_path}/raw_ephys_data"
        
        # call the bash command to remove the files
        remove_from_path_command = "find " + dir_to_delete + " -type d -exec rm -rf {} +"
        subprocess.run(remove_from_path_command, shell=True)
        
        # Then, remove the directory itself
        remove_dir_command = "find " + session_path + " -type d -name 'raw_ephys_data' -exec rm -r {} +"
        subprocess.run(remove_dir_command, shell=True)
# Out:
# Probe: ['3d3d5a5e-df26-43ee-80b6-2d72d85668a5'], Probe name: ['probe00']
# probe00
# <class 'list'>
# 3
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.cbin: 100%|██████████| 2.98G/2.98G [00:31<00:00, 94.2MB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.ch: 100%|██████████| 131k/131k [00:00<00:00, 338kB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.meta: 100%|██████████| 14.0k/14.0k [00:00<00:00, 78.2kB/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004897356033325195
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 38.81415939331055
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11397043)
# done, time elapsed: 1201.4091582298279
# destriped loaded...
# Probe: ['27bac116-ea57-4512-ad35-714a62d259cd', 'eebcaf65-7fa4-4118-869d-a084e84530e2'], Probe name: ['probe00', 'probe01']
# probe00
# <class 'list'>
# 3
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/.nfs00000000000cdb9000000294’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data/probe00/.nfs00000000000cdb9000000294’: Device or resource busy
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.cbin: 100%|██████████| 2.89G/2.89G [00:25<00:00, 114MB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.ch: 100%|██████████| 132k/132k [00:00<00:00, 579kB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/_spikeglx_ephysData_g0_t0.imec0.lf.meta: 100%|██████████| 14.0k/14.0k [00:00<00:00, 73.0kB/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004518747329711914
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 38.444119930267334
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11471112)
# done, time elapsed: 2896.6871247291565
# destriped loaded...
# probe01
# <class 'list'>
# 3
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.cbin: 100%|██████████| 2.87G/2.87G [00:26<00:00, 107MB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.ch: 100%|██████████| 132k/132k [00:00<00:00, 427kB/s]
# /space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/_spikeglx_ephysData_g0_t0.imec1.lf.meta: 100%|██████████| 14.0k/14.0k [00:00<00:00, 73.3kB/s]
# sr = spikeglx.Reader(bin_file)
# done, time elapsed: 0.004548072814941406
# raw = sr[:, :-sr.nsync].T
# done, time elapsed: 44.42645740509033
# destriped = destripe(raw, fs=sr.fs)
# destripped shape : (384, 11471128)
# done, time elapsed: 1065.1039772033691
# destriped loaded...
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00’: Directory not empty
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb9600000295’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb9600000295’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy

# %%
#Searching for datasets
brain_acronym = 'CA1'
# query sessions endpoint
sessions, sess_details = one.search(atlas_acronym=brain_acronym, query_type='remote', details=True)
print(f'No. of detected sessions: {len(sessions)}')

# query insertions endpoint
insertions = one.search_insertions(atlas_acronym=brain_acronym)
print(f'No. of detected insertions: {len(insertions)}')
# Out:
# No. of detected sessions: 201
# No. of detected insertions: 201

# %%
[x for x in sess_details ]
# Out:
# [{'id': 'ebce500b-c530-47de-8cb1-963c552703ea',
#   'subject': 'MFD_09',
#   'start_time': '2023-10-19T12:54:25.961859',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ebce500b-c530-47de-8cb1-963c552703ea',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2023, 10, 19)},
#  {'id': '5ae68c54-2897-4d3a-8120-426150704385',
#   'subject': 'MFD_08',
#   'start_time': '2023-09-07T14:48:07.791158',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5ae68c54-2897-4d3a-8120-426150704385',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2023, 9, 7)},
#  {'id': '15b69921-d471-4ded-8814-2adad954bcd8',
#   'subject': 'MFD_07',
#   'start_time': '2023-08-31T15:17:16.846656',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/15b69921-d471-4ded-8814-2adad954bcd8',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2023, 8, 31)},
#  {'id': 'caa5dddc-9290-4e27-9f5e-575ba3598614',
#   'subject': 'NR_0031',
#   'start_time': '2023-07-14T15:17:40.935162',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/caa5dddc-9290-4e27-9f5e-575ba3598614',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 7, 14)},
#  {'id': 'caa5dddc-9290-4e27-9f5e-575ba3598614',
#   'subject': 'NR_0031',
#   'start_time': '2023-07-14T15:17:40.935162',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/caa5dddc-9290-4e27-9f5e-575ba3598614',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 7, 14)},
#  {'id': '642c97ea-fe89-4ec9-8629-5e492ea4019d',
#   'subject': 'NR_0031',
#   'start_time': '2023-07-12T14:17:48.191150',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/642c97ea-fe89-4ec9-8629-5e492ea4019d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 7, 12)},
#  {'id': '642c97ea-fe89-4ec9-8629-5e492ea4019d',
#   'subject': 'NR_0031',
#   'start_time': '2023-07-12T14:17:48.191150',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/642c97ea-fe89-4ec9-8629-5e492ea4019d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 7, 12)},
#  {'id': '0cf6d255-8f2f-463e-84fb-c54bacb79f51',
#   'subject': 'PL050',
#   'start_time': '2023-06-07T16:04:02.725885',
#   'number': 1,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0cf6d255-8f2f-463e-84fb-c54bacb79f51',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2023, 6, 7)},
#  {'id': 'a2b9fbbe-79fc-4166-a16e-b307813a2f06',
#   'subject': 'PL035',
#   'start_time': '2023-04-12T14:47:28.397552',
#   'number': 1,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a2b9fbbe-79fc-4166-a16e-b307813a2f06',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2023, 4, 12)},
#  {'id': 'f56194bc-8215-4ae8-bc6a-89781ad8e050',
#   'subject': 'NR_0028',
#   'start_time': '2023-03-15T12:29:09.139016',
#   'number': 3,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/f56194bc-8215-4ae8-bc6a-89781ad8e050',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 3, 15)},
#  {'id': '2d9bfc10-59fb-424a-b699-7c42f86c7871',
#   'subject': 'NR_0024',
#   'start_time': '2023-02-03T12:01:59',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/2d9bfc10-59fb-424a-b699-7c42f86c7871',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 2, 3)},
#  {'id': '3bcb81b4-d9ca-4fc9-a1cd-353a966239ca',
#   'subject': 'NR_0024',
#   'start_time': '2023-01-19T14:08:54',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3bcb81b4-d9ca-4fc9-a1cd-353a966239ca',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 1, 19)},
#  {'id': '3bcb81b4-d9ca-4fc9-a1cd-353a966239ca',
#   'subject': 'NR_0024',
#   'start_time': '2023-01-19T14:08:54',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3bcb81b4-d9ca-4fc9-a1cd-353a966239ca',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2023, 1, 19)},
#  {'id': '233617ec-c5cf-4eda-afc8-3b1d94f36d73',
#   'subject': 'PL030',
#   'start_time': '2022-10-17T13:28:01.855602',
#   'number': 2,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/233617ec-c5cf-4eda-afc8-3b1d94f36d73',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2022, 10, 17)},
#  {'id': 'a2ec6341-c55f-48a0-a23b-0ef2f5b1d71e',
#   'subject': 'NYU-65',
#   'start_time': '2022-09-12T15:33:06',
#   'number': 2,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a2ec6341-c55f-48a0-a23b-0ef2f5b1d71e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.4',
#   'date': datetime.date(2022, 9, 12)},
#  {'id': '6c6b0d06-6039-4525-a74b-58cfaa1d3a60',
#   'subject': 'NR_0027',
#   'start_time': '2022-08-19T15:38:11',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6c6b0d06-6039-4525-a74b-58cfaa1d3a60',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2022, 8, 19)},
#  {'id': '6c6b0d06-6039-4525-a74b-58cfaa1d3a60',
#   'subject': 'NR_0027',
#   'start_time': '2022-08-19T15:38:11',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6c6b0d06-6039-4525-a74b-58cfaa1d3a60',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2022, 8, 19)},
#  {'id': 'dc962048-89bb-4e6a-96a9-b062a2be1426',
#   'subject': 'UCLA048',
#   'start_time': '2022-08-16T16:11:36.075354',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/dc962048-89bb-4e6a-96a9-b062a2be1426',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2022, 8, 16)},
#  {'id': 'dc962048-89bb-4e6a-96a9-b062a2be1426',
#   'subject': 'UCLA048',
#   'start_time': '2022-08-16T16:11:36.075354',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/dc962048-89bb-4e6a-96a9-b062a2be1426',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2022, 8, 16)},
#  {'id': '8a1cf4ef-06e3-4c72-9bc7-e1baa189841b',
#   'subject': 'UCLA049',
#   'start_time': '2022-08-12T16:56:27.875789',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/8a1cf4ef-06e3-4c72-9bc7-e1baa189841b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.2',
#   'date': datetime.date(2022, 8, 12)},
#  {'id': '0841d188-8ef2-4f20-9828-76a94d5343a4',
#   'subject': 'UCLA049',
#   'start_time': '2022-08-02T16:36:06.329463',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0841d188-8ef2-4f20-9828-76a94d5343a4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.1',
#   'date': datetime.date(2022, 8, 2)},
#  {'id': '0841d188-8ef2-4f20-9828-76a94d5343a4',
#   'subject': 'UCLA049',
#   'start_time': '2022-08-02T16:36:06.329463',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0841d188-8ef2-4f20-9828-76a94d5343a4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.1',
#   'date': datetime.date(2022, 8, 2)},
#  {'id': '239dd3c9-35f3-4462-95ee-91b822a22e6b',
#   'subject': 'ZFM-04308',
#   'start_time': '2022-07-26T12:05:47',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/239dd3c9-35f3-4462-95ee-91b822a22e6b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2022, 7, 26)},
#  {'id': '687017d4-c9fc-458f-a7d5-0979fe1a7470',
#   'subject': 'UCLA052',
#   'start_time': '2022-07-12T17:48:32',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/687017d4-c9fc-458f-a7d5-0979fe1a7470',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.6.1',
#   'date': datetime.date(2022, 7, 12)},
#  {'id': '27ef44c0-acb2-4220-b776-477d0d5abd35',
#   'subject': 'NR_0021',
#   'start_time': '2022-06-28T12:41:04.697544',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/27ef44c0-acb2-4220-b776-477d0d5abd35',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 6, 28)},
#  {'id': 'a2701b93-d8e1-47e9-a819-f1063046f3e7',
#   'subject': 'KS096',
#   'start_time': '2022-06-21T17:44:14.985000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a2701b93-d8e1-47e9-a819-f1063046f3e7',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 6, 21)},
#  {'id': '446f4724-1690-49f9-819a-2bd8e2ea88ce',
#   'subject': 'KS096',
#   'start_time': '2022-06-20T16:46:15.609000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/446f4724-1690-49f9-819a-2bd8e2ea88ce',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 6, 20)},
#  {'id': '8928f98a-b411-497e-aa4b-aa752434686d',
#   'subject': 'KS096',
#   'start_time': '2022-06-17T15:27:55.990000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/8928f98a-b411-497e-aa4b-aa752434686d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 6, 17)},
#  {'id': '3f859b5c-e73a-4044-b49e-34bb81e96715',
#   'subject': 'KS094',
#   'start_time': '2022-06-17T11:52:31.281000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3f859b5c-e73a-4044-b49e-34bb81e96715',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 6, 17)},
#  {'id': 'd901aff5-2250-467a-b4a1-0cb9729df9e2',
#   'subject': 'NR_0020',
#   'start_time': '2022-05-11T13:32:47.764358',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d901aff5-2250-467a-b4a1-0cb9729df9e2',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 5, 11)},
#  {'id': '5b49aca6-a6f4-4075-931a-617ad64c219c',
#   'subject': 'NR_0020',
#   'start_time': '2022-05-10T18:07:06.273804',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5b49aca6-a6f4-4075-931a-617ad64c219c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 5, 10)},
#  {'id': 'eacc49a9-f3a1-49f1-b87f-0972f90ee837',
#   'subject': 'NR_0020',
#   'start_time': '2022-05-09T14:19:25.159439',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/eacc49a9-f3a1-49f1-b87f-0972f90ee837',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 5, 9)},
#  {'id': '3e6a97d3-3991-49e2-b346-6948cb4580fb',
#   'subject': 'NR_0020',
#   'start_time': '2022-05-08T13:39:14.170541',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3e6a97d3-3991-49e2-b346-6948cb4580fb',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 5, 8)},
#  {'id': '3e6a97d3-3991-49e2-b346-6948cb4580fb',
#   'subject': 'NR_0020',
#   'start_time': '2022-05-08T13:39:14.170541',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3e6a97d3-3991-49e2-b346-6948cb4580fb',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 5, 8)},
#  {'id': '9b528ad0-4599-4a55-9148-96cc1d93fb24',
#   'subject': 'NR_0019',
#   'start_time': '2022-04-29T19:31:15.276863',
#   'number': 1,
#   'lab': 'steinmetzlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/9b528ad0-4599-4a55-9148-96cc1d93fb24',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 4, 29)},
#  {'id': 'a4747ac8-6a75-444f-b99b-696fff0243fd',
#   'subject': 'SWC_066',
#   'start_time': '2022-04-28T18:08:24.122809',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a4747ac8-6a75-444f-b99b-696fff0243fd',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 4, 28)},
#  {'id': '91bac580-76ed-41ab-ac07-89051f8d7f6e',
#   'subject': 'UCLA044',
#   'start_time': '2022-04-14T16:36:16.565033',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/91bac580-76ed-41ab-ac07-89051f8d7f6e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 4, 14)},
#  {'id': '0c828385-6dd6-4842-a702-c5075f5f5e81',
#   'subject': 'UCLA015',
#   'start_time': '2022-03-31T17:24:05.233956',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0c828385-6dd6-4842-a702-c5075f5f5e81',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 3, 31)},
#  {'id': 'e45481fa-be22-4365-972c-e7404ed8ab5a',
#   'subject': 'KS086',
#   'start_time': '2022-03-15T15:38:13.431000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e45481fa-be22-4365-972c-e7404ed8ab5a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 3, 15)},
#  {'id': 'e2b845a1-e313-4a08-bc61-a5f662ed295e',
#   'subject': 'UCLA036',
#   'start_time': '2022-03-09T16:49:56.407522',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e2b845a1-e313-4a08-bc61-a5f662ed295e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 3, 9)},
#  {'id': 'e2b845a1-e313-4a08-bc61-a5f662ed295e',
#   'subject': 'UCLA036',
#   'start_time': '2022-03-09T16:49:56.407522',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e2b845a1-e313-4a08-bc61-a5f662ed295e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 3, 9)},
#  {'id': '9a6e127b-bb07-4be2-92e2-53dd858c2762',
#   'subject': 'PL015',
#   'start_time': '2022-02-21T16:49:18.494416',
#   'number': 2,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/9a6e127b-bb07-4be2-92e2-53dd858c2762',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 2, 21)},
#  {'id': '64977c74-9c04-437a-9ea1-50386c4996db',
#   'subject': 'PL015',
#   'start_time': '2022-02-20T16:09:07.326998',
#   'number': 1,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/64977c74-9c04-437a-9ea1-50386c4996db',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.3',
#   'date': datetime.date(2022, 2, 20)},
#  {'id': '111c1762-7908-47e0-9f40-2f2ee55b6505',
#   'subject': 'UCLA033',
#   'start_time': '2022-02-15T16:57:00.789395',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/111c1762-7908-47e0-9f40-2f2ee55b6505',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 2, 15)},
#  {'id': '2bdf206a-820f-402f-920a-9e86cd5388a4',
#   'subject': 'UCLA037',
#   'start_time': '2022-02-02T17:13:16.755421',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/2bdf206a-820f-402f-920a-9e86cd5388a4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 2, 2)},
#  {'id': '2bdf206a-820f-402f-920a-9e86cd5388a4',
#   'subject': 'UCLA037',
#   'start_time': '2022-02-02T17:13:16.755421',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/2bdf206a-820f-402f-920a-9e86cd5388a4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 2, 2)},
#  {'id': '1b715600-0cbc-442c-bd00-5b0ac2865de1',
#   'subject': 'KS084',
#   'start_time': '2022-01-31T14:47:03.463000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1b715600-0cbc-442c-bd00-5b0ac2865de1',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2022, 1, 31)},
#  {'id': '8a3a0197-b40a-449f-be55-c00b23253bbf',
#   'subject': 'UCLA034',
#   'start_time': '2022-01-25T15:07:55',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/8a3a0197-b40a-449f-be55-c00b23253bbf',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2022, 1, 25)},
#  {'id': '5dcee0eb-b34d-4652-acc3-d10afc6eae68',
#   'subject': 'KS075',
#   'start_time': '2021-12-09T14:17:29.797000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5dcee0eb-b34d-4652-acc3-d10afc6eae68',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2021, 12, 9)},
#  {'id': 'c7bf2d49-4937-4597-b307-9f39cb1c7b16',
#   'subject': 'KS074',
#   'start_time': '2021-11-22T17:41:18',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/c7bf2d49-4937-4597-b307-9f39cb1c7b16',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld',
#   'date': datetime.date(2021, 11, 22)},
#  {'id': '8b1f4024-3d96-4ee7-95f9-8a1dfd4ce4ef',
#   'subject': 'PL017',
#   'start_time': '2021-11-09T19:32:47.033823',
#   'number': 1,
#   'lab': 'hausserlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/8b1f4024-3d96-4ee7-95f9-8a1dfd4ce4ef',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.5.0',
#   'date': datetime.date(2021, 11, 9)},
#  {'id': '36dee8f1-a58f-4fca-bf10-9edd6baf07ef',
#   'subject': 'UCLA005',
#   'start_time': '2021-08-03T16:48:39.823893',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/36dee8f1-a58f-4fca-bf10-9edd6baf07ef',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 8, 3)},
#  {'id': 'd57df551-6dcb-4242-9c72-b806cff5613a',
#   'subject': 'UCLA005',
#   'start_time': '2021-08-02T16:45:22',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d57df551-6dcb-4242-9c72-b806cff5613a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 8, 2)},
#  {'id': '824cf03d-4012-4ab1-b499-c83a92c5589e',
#   'subject': 'UCLA011',
#   'start_time': '2021-07-20T18:15:30',
#   'number': 1,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/824cf03d-4012-4ab1-b499-c83a92c5589e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 7, 20)},
#  {'id': '7502ae93-7437-4bcd-9e14-d73b51193656',
#   'subject': 'ibl_witten_32',
#   'start_time': '2021-07-20T16:15:28',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7502ae93-7437-4bcd-9e14-d73b51193656',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 7, 20)},
#  {'id': '51e53aff-1d5d-4182-a684-aba783d50ae5',
#   'subject': 'NYU-45',
#   'start_time': '2021-07-19T14:24:23.683992',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/51e53aff-1d5d-4182-a684-aba783d50ae5',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 7, 19)},
#  {'id': '1f095590-6669-46c9-986b-ccaf0620c5e9',
#   'subject': 'UCLA012',
#   'start_time': '2021-07-07T17:41:16',
#   'number': 2,
#   'lab': 'churchlandlab_ucla',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1f095590-6669-46c9-986b-ccaf0620c5e9',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 7, 7)},
#  {'id': '3d59aa1a-b4ba-47fe-b9cf-741b5fdb0c7b',
#   'subject': 'NYU-48',
#   'start_time': '2021-07-02T15:28:23.348923',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3d59aa1a-b4ba-47fe-b9cf-741b5fdb0c7b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 7, 2)},
#  {'id': 'c51f34d8-42f6-4c9c-bb5b-669fd9c42cd9',
#   'subject': 'NYU-48',
#   'start_time': '2021-06-28T15:35:24.550806',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/c51f34d8-42f6-4c9c-bb5b-669fd9c42cd9',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 28)},
#  {'id': '0802ced5-33a3-405e-8336-b65ebc5cb07c',
#   'subject': 'ZFM-02373',
#   'start_time': '2021-06-23T10:46:45',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0802ced5-33a3-405e-8336-b65ebc5cb07c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 23)},
#  {'id': '0802ced5-33a3-405e-8336-b65ebc5cb07c',
#   'subject': 'ZFM-02373',
#   'start_time': '2021-06-23T10:46:45',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0802ced5-33a3-405e-8336-b65ebc5cb07c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 23)},
#  {'id': 'f140a2ec-fd49-4814-994a-fe3476f14e66',
#   'subject': 'NYU-47',
#   'start_time': '2021-06-21T17:39:08.652187',
#   'number': 3,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/f140a2ec-fd49-4814-994a-fe3476f14e66',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 21)},
#  {'id': '0cc486c3-8c7b-494d-aa04-b70e2690bcba',
#   'subject': 'ibl_witten_29',
#   'start_time': '2021-06-09T11:37:42.691314',
#   'number': 2,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0cc486c3-8c7b-494d-aa04-b70e2690bcba',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 9)},
#  {'id': 'd2832a38-27f6-452d-91d6-af72d794136c',
#   'subject': 'ibl_witten_29',
#   'start_time': '2021-06-08T13:02:35',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d2832a38-27f6-452d-91d6-af72d794136c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 8)},
#  {'id': 'a4a74102-2af5-45dc-9e41-ef7f5aed88be',
#   'subject': 'ZFM-02368',
#   'start_time': '2021-06-01T16:24:33.849360',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a4a74102-2af5-45dc-9e41-ef7f5aed88be',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 1)},
#  {'id': '88224abb-5746-431f-9c17-17d7ef806e6a',
#   'subject': 'ZFM-02372',
#   'start_time': '2021-06-01T13:15:33',
#   'number': 2,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/88224abb-5746-431f-9c17-17d7ef806e6a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 6, 1)},
#  {'id': '72cb5550-43b4-4ef0-add5-e4adfdfb5e02',
#   'subject': 'ZFM-02369',
#   'start_time': '2021-05-19T16:02:31',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/72cb5550-43b4-4ef0-add5-e4adfdfb5e02',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 5, 19)},
#  {'id': '3555ce3a-ccce-4b7e-8eb1-c2571913599e',
#   'subject': 'KS052',
#   'start_time': '2021-05-14T14:44:28',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3555ce3a-ccce-4b7e-8eb1-c2571913599e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 5, 14)},
#  {'id': '0a018f12-ee06-4b11-97aa-bbbff5448e9f',
#   'subject': 'KS051',
#   'start_time': '2021-05-11T14:24:53',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0a018f12-ee06-4b11-97aa-bbbff5448e9f',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 5, 11)},
#  {'id': '6ed57216-498d-48a6-b48b-a243a34710ea',
#   'subject': 'NYU-39',
#   'start_time': '2021-05-10T15:33:49.023776',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6ed57216-498d-48a6-b48b-a243a34710ea',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 5, 10)},
#  {'id': 'b22f694e-4a34-4142-ab9d-2556c3487086',
#   'subject': 'KS055',
#   'start_time': '2021-05-02T18:59:07.448000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/b22f694e-4a34-4142-ab9d-2556c3487086',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 5, 2)},
#  {'id': '30c4e2ab-dffc-499d-aae4-e51d6b3218c2',
#   'subject': 'ZFM-02370',
#   'start_time': '2021-04-29T15:32:26',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/30c4e2ab-dffc-499d-aae4-e51d6b3218c2',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 4, 29)},
#  {'id': '1a507308-c63a-4e02-8f32-3239a07dc578',
#   'subject': 'ZFM-01935',
#   'start_time': '2021-02-03T16:29:23.315284',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1a507308-c63a-4e02-8f32-3239a07dc578',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 2, 3)},
#  {'id': '1a507308-c63a-4e02-8f32-3239a07dc578',
#   'subject': 'ZFM-01935',
#   'start_time': '2021-02-03T16:29:23.315284',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1a507308-c63a-4e02-8f32-3239a07dc578',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 2, 3)},
#  {'id': 'a9138924-4395-4981-83d1-530f6ff7c8fc',
#   'subject': 'ibl_witten_26',
#   'start_time': '2021-01-28T15:48:40.399464',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a9138924-4395-4981-83d1-530f6ff7c8fc',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 28)},
#  {'id': 'ff96bfe1-d925-4553-94b5-bf8297adf259',
#   'subject': 'ibl_witten_26',
#   'start_time': '2021-01-27T16:23:21',
#   'number': 2,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ff96bfe1-d925-4553-94b5-bf8297adf259',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 27)},
#  {'id': '7af49c00-63dd-4fed-b2e0-1b3bd945b20b',
#   'subject': 'NYU-37',
#   'start_time': '2021-01-25T15:32:41.052960',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7af49c00-63dd-4fed-b2e0-1b3bd945b20b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 25)},
#  {'id': '73918ae1-e4fd-4c18-b132-00cb555b1ad2',
#   'subject': 'ibl_witten_27',
#   'start_time': '2021-01-21T17:05:26',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/73918ae1-e4fd-4c18-b132-00cb555b1ad2',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 21)},
#  {'id': '73918ae1-e4fd-4c18-b132-00cb555b1ad2',
#   'subject': 'ibl_witten_27',
#   'start_time': '2021-01-21T17:05:26',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/73918ae1-e4fd-4c18-b132-00cb555b1ad2',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 21)},
#  {'id': 'f304211a-81b1-446f-a435-25e589fe3a5a',
#   'subject': 'ibl_witten_27',
#   'start_time': '2021-01-20T20:03:41',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/f304211a-81b1-446f-a435-25e589fe3a5a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 20)},
#  {'id': 'd0ea3148-948d-4817-94f8-dcaf2342bbbe',
#   'subject': 'ZFM-01936',
#   'start_time': '2021-01-19T17:15:10',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d0ea3148-948d-4817-94f8-dcaf2342bbbe',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2021, 1, 19)},
#  {'id': '0cad7ea8-8e6c-4ad1-a5c5-53fbb2df1a63',
#   'subject': 'KS045',
#   'start_time': '2020-12-09T23:36:34.007000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0cad7ea8-8e6c-4ad1-a5c5-53fbb2df1a63',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 9)},
#  {'id': '781b35fd-e1f0-4d14-b2bb-95b7263082bb',
#   'subject': 'KS044',
#   'start_time': '2020-12-09T21:29:24.224000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/781b35fd-e1f0-4d14-b2bb-95b7263082bb',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 9)},
#  {'id': '3638d102-e8b6-4230-8742-e548cd87a949',
#   'subject': 'SWC_058',
#   'start_time': '2020-12-07T16:43:05.826338',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/3638d102-e8b6-4230-8742-e548cd87a949',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 7)},
#  {'id': 'd9f0c293-df4c-410a-846d-842e47c6b502',
#   'subject': 'ibl_witten_25',
#   'start_time': '2020-12-07T15:37:42',
#   'number': 2,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d9f0c293-df4c-410a-846d-842e47c6b502',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 7)},
#  {'id': '4333b9f7-a4e7-4b83-a457-7122ae080034',
#   'subject': 'KS043',
#   'start_time': '2020-12-05T23:03:26.710000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/4333b9f7-a4e7-4b83-a457-7122ae080034',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 5)},
#  {'id': '0ac8d013-b91e-4732-bc7b-a1164ff3e445',
#   'subject': 'KS046',
#   'start_time': '2020-12-02T18:18:58.352000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0ac8d013-b91e-4732-bc7b-a1164ff3e445',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 2)},
#  {'id': '8a039e2b-637e-45ed-8da6-0641924626f0',
#   'subject': 'SWC_061',
#   'start_time': '2020-12-01T18:33:24.996935',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/8a039e2b-637e-45ed-8da6-0641924626f0',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 1)},
#  {'id': 'c4432264-e1ae-446f-8a07-6280abade813',
#   'subject': 'ZFM-01576',
#   'start_time': '2020-12-01T10:59:12.153826',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/c4432264-e1ae-446f-8a07-6280abade813',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 12, 1)},
#  {'id': 'd7e60cc3-6020-429e-a654-636c6cc677ea',
#   'subject': 'SWC_061',
#   'start_time': '2020-11-30T19:34:05.062484',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d7e60cc3-6020-429e-a654-636c6cc677ea',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 11, 30)},
#  {'id': '81a1dca0-cc90-47c5-afe3-c277319c47c8',
#   'subject': 'SWC_060',
#   'start_time': '2020-11-26T17:22:03.545441',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/81a1dca0-cc90-47c5-afe3-c277319c47c8',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 11, 26)},
#  {'id': '875c1e5c-f7ec-45ac-ab82-ecfe7276a707',
#   'subject': 'SWC_060',
#   'start_time': '2020-11-25T13:17:54.132432',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/875c1e5c-f7ec-45ac-ab82-ecfe7276a707',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 11, 25)},
#  {'id': 'dac3a4c1-b666-4de0-87e8-8c514483cacf',
#   'subject': 'SWC_060',
#   'start_time': '2020-11-24T16:39:18.082333',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/dac3a4c1-b666-4de0-87e8-8c514483cacf',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 11, 24)},
#  {'id': '5d6aa933-4b00-4e99-ae2d-5003657592e9',
#   'subject': 'ZFM-01577',
#   'start_time': '2020-10-29T15:38:41',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5d6aa933-4b00-4e99-ae2d-5003657592e9',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 29)},
#  {'id': '09b2c4d1-058d-4c84-9fd4-97530f85baf6',
#   'subject': 'ZFM-01577',
#   'start_time': '2020-10-28T15:04:48',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/09b2c4d1-058d-4c84-9fd4-97530f85baf6',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 28)},
#  {'id': 'de588204-8fd6-4ce3-92da-7a6d1dcae238',
#   'subject': 'ZFM-01577',
#   'start_time': '2020-10-27T17:01:22',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/de588204-8fd6-4ce3-92da-7a6d1dcae238',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 27)},
#  {'id': '7cb81727-2097-4b52-b480-c89867b5b34c',
#   'subject': 'SWC_052',
#   'start_time': '2020-10-22T22:28:49.023280',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7cb81727-2097-4b52-b480-c89867b5b34c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 22)},
#  {'id': '7cb81727-2097-4b52-b480-c89867b5b34c',
#   'subject': 'SWC_052',
#   'start_time': '2020-10-22T22:28:49.023280',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7cb81727-2097-4b52-b480-c89867b5b34c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 22)},
#  {'id': '5b609f9b-75cb-43d3-9c39-b5b4b7a0db67',
#   'subject': 'ZFM-01592',
#   'start_time': '2020-10-21T14:49:08',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5b609f9b-75cb-43d3-9c39-b5b4b7a0db67',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 21)},
#  {'id': '746d1902-fa59-4cab-b0aa-013be36060d5',
#   'subject': 'ZFM-01592',
#   'start_time': '2020-10-20T13:44:19',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/746d1902-fa59-4cab-b0aa-013be36060d5',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 20)},
#  {'id': 'cde63527-7f5a-4cc3-8ac2-215d82e7da26',
#   'subject': 'DY_018',
#   'start_time': '2020-10-20T10:30:43.402364',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/cde63527-7f5a-4cc3-8ac2-215d82e7da26',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 20)},
#  {'id': '7691eeb3-715b-4571-8fda-6bb57aab8253',
#   'subject': 'NYU-30',
#   'start_time': '2020-10-19T16:38:28.477083',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7691eeb3-715b-4571-8fda-6bb57aab8253',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 19)},
#  {'id': 'e8b4fda3-7fe4-4706-8ec2-91036cfee6bd',
#   'subject': 'DY_018',
#   'start_time': '2020-10-17T10:46:03.288322',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e8b4fda3-7fe4-4706-8ec2-91036cfee6bd',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 17)},
#  {'id': '54238fd6-d2d0-4408-b1a9-d19d24fd29ce',
#   'subject': 'DY_018',
#   'start_time': '2020-10-15T10:30:19.139717',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/54238fd6-d2d0-4408-b1a9-d19d24fd29ce',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 15)},
#  {'id': 'eebacd5a-7dcd-4ba6-9dff-ec2a4d2f19e0',
#   'subject': 'SWC_054',
#   'start_time': '2020-10-09T18:10:43.904513',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/eebacd5a-7dcd-4ba6-9dff-ec2a4d2f19e0',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 9)},
#  {'id': '6c6983ef-7383-4989-9183-32b1a300d17a',
#   'subject': 'SWC_054',
#   'start_time': '2020-10-07T18:20:13.449770',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6c6983ef-7383-4989-9183-32b1a300d17a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 7)},
#  {'id': '56b57c38-2699-4091-90a8-aba35103155e',
#   'subject': 'SWC_054',
#   'start_time': '2020-10-05T19:15:05.974514',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/56b57c38-2699-4091-90a8-aba35103155e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 5)},
#  {'id': 'e26c6001-defe-42a9-9ded-368e3f03ac61',
#   'subject': 'NYU-25',
#   'start_time': '2020-10-05T14:55:12.288434',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e26c6001-defe-42a9-9ded-368e3f03ac61',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 5)},
#  {'id': 'a52f5a1b-7f45-4f2c-89a9-fb199d2a0d63',
#   'subject': 'ibl_witten_23',
#   'start_time': '2020-10-01T14:57:37',
#   'number': 5,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a52f5a1b-7f45-4f2c-89a9-fb199d2a0d63',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 10, 1)},
#  {'id': 'f7335a49-4a98-46d2-a8ce-d041d2eac1d6',
#   'subject': 'DY_020',
#   'start_time': '2020-09-30T10:38:11.795687',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/f7335a49-4a98-46d2-a8ce-d041d2eac1d6',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 30)},
#  {'id': '4a45c8ba-db6f-4f11-9403-56e06a33dfa4',
#   'subject': 'DY_020',
#   'start_time': '2020-09-29T11:34:40.078512',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/4a45c8ba-db6f-4f11-9403-56e06a33dfa4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 29)},
#  {'id': '7b26ce84-07f9-43d1-957f-bc72aeb730a3',
#   'subject': 'NYU-27',
#   'start_time': '2020-09-28T15:05:26.917108',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/7b26ce84-07f9-43d1-957f-bc72aeb730a3',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 28)},
#  {'id': '754b74d5-7a06-4004-ae0c-72a10b6ed2e6',
#   'subject': 'NYU-29',
#   'start_time': '2020-09-21T14:37:55',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/754b74d5-7a06-4004-ae0c-72a10b6ed2e6',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 21)},
#  {'id': 'c6db3304-c906-400c-aa0f-45dd3945b2ea',
#   'subject': 'SWC_043',
#   'start_time': '2020-09-20T19:12:54.571582',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/c6db3304-c906-400c-aa0f-45dd3945b2ea',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 20)},
#  {'id': '695a6073-eae0-49e0-bb0f-e9e57a9275b9',
#   'subject': 'SWC_043',
#   'start_time': '2020-09-17T18:30:54.821845',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/695a6073-eae0-49e0-bb0f-e9e57a9275b9',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 17)},
#  {'id': '6f09ba7e-e3ce-44b0-932b-c003fb44fb89',
#   'subject': 'SWC_043',
#   'start_time': '2020-09-16T16:20:54.130243',
#   'number': 2,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6f09ba7e-e3ce-44b0-932b-c003fb44fb89',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 16)},
#  {'id': 'fcd49e34-f07b-441c-b2ac-cb8c462ec5ac',
#   'subject': 'CSH_ZAD_029',
#   'start_time': '2020-09-14T08:08:05',
#   'number': 1,
#   'lab': 'zadorlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/fcd49e34-f07b-441c-b2ac-cb8c462ec5ac',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 14)},
#  {'id': 'fcd49e34-f07b-441c-b2ac-cb8c462ec5ac',
#   'subject': 'CSH_ZAD_029',
#   'start_time': '2020-09-14T08:08:05',
#   'number': 1,
#   'lab': 'zadorlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/fcd49e34-f07b-441c-b2ac-cb8c462ec5ac',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 14)},
#  {'id': '1ec23a70-b94b-4e9c-a0df-8c2151da3761',
#   'subject': 'CSH_ZAD_029',
#   'start_time': '2020-09-13T07:52:15',
#   'number': 1,
#   'lab': 'zadorlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1ec23a70-b94b-4e9c-a0df-8c2151da3761',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 13)},
#  {'id': '1ec23a70-b94b-4e9c-a0df-8c2151da3761',
#   'subject': 'CSH_ZAD_029',
#   'start_time': '2020-09-13T07:52:15',
#   'number': 1,
#   'lab': 'zadorlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/1ec23a70-b94b-4e9c-a0df-8c2151da3761',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.4.2',
#   'date': datetime.date(2020, 9, 13)},
# ...
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 21)},
#  {'id': '83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4',
#   'subject': 'CSHL052',
#   'start_time': '2020-02-20T13:15:02',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 20)},
#  {'id': '83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4',
#   'subject': 'CSHL052',
#   'start_time': '2020-02-20T13:15:02',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/83e77b4b-dfa0-4af9-968b-7ea0c7a0c7e4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 20)},
#  {'id': '5386aba9-9b97-4557-abcd-abc2da66b863',
#   'subject': 'CSHL052',
#   'start_time': '2020-02-19T15:33:58',
#   'number': 2,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/5386aba9-9b97-4557-abcd-abc2da66b863',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 19)},
#  {'id': '6713a4a7-faed-4df2-acab-ee4e63326f8d',
#   'subject': 'NYU-11',
#   'start_time': '2020-02-18T14:25:54',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6713a4a7-faed-4df2-acab-ee4e63326f8d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 18)},
#  {'id': '0cbeae00-e229-4b7d-bdcc-1b0569d7e0c3',
#   'subject': 'CSHL055',
#   'start_time': '2020-02-17T14:07:14',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0cbeae00-e229-4b7d-bdcc-1b0569d7e0c3',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 17)},
#  {'id': '38d95489-2e82-412a-8c1a-c5377b5f1555',
#   'subject': 'SWC_023',
#   'start_time': '2020-02-13T15:36:50.234590',
#   'number': 1,
#   'lab': 'mrsicflogellab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/38d95489-2e82-412a-8c1a-c5377b5f1555',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 13)},
#  {'id': '572a95d1-39ca-42e1-8424-5c9ffcb2df87',
#   'subject': 'KS020',
#   'start_time': '2020-02-07T15:54:19.001000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/572a95d1-39ca-42e1-8424-5c9ffcb2df87',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 7)},
#  {'id': 'ecb5520d-1358-434c-95ec-93687ecd1396',
#   'subject': 'CSHL051',
#   'start_time': '2020-02-05T14:12:27',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ecb5520d-1358-434c-95ec-93687ecd1396',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 5)},
#  {'id': 'ecb5520d-1358-434c-95ec-93687ecd1396',
#   'subject': 'CSHL051',
#   'start_time': '2020-02-05T14:12:27',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ecb5520d-1358-434c-95ec-93687ecd1396',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 2, 5)},
#  {'id': 'f8d5c8b0-b931-4151-b86c-c471e2e80e5d',
#   'subject': 'ZM_2241',
#   'start_time': '2020-01-31T14:36:39',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/f8d5c8b0-b931-4151-b86c-c471e2e80e5d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 31)},
#  {'id': 'ee40aece-cffd-4edb-a4b6-155f158c666a',
#   'subject': 'ZM_2241',
#   'start_time': '2020-01-30T15:43:49',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ee40aece-cffd-4edb-a4b6-155f158c666a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 30)},
#  {'id': '0deb75fb-9088-42d9-b744-012fb8fc4afb',
#   'subject': 'CSHL053',
#   'start_time': '2020-01-30T13:24:09',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/0deb75fb-9088-42d9-b744-012fb8fc4afb',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 30)},
#  {'id': '12dc8b34-b18e-4cdd-90a9-da134a9be79c',
#   'subject': 'CSHL053',
#   'start_time': '2020-01-29T16:19:33',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/12dc8b34-b18e-4cdd-90a9-da134a9be79c',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 29)},
#  {'id': '02fbb6da-3034-47d6-a61b-7d06c796a830',
#   'subject': 'DY_010',
#   'start_time': '2020-01-29T14:24:50.260617',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/02fbb6da-3034-47d6-a61b-7d06c796a830',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 29)},
#  {'id': '931a70ae-90ee-448e-bedb-9d41f3eda647',
#   'subject': 'DY_010',
#   'start_time': '2020-01-28T11:34:01.365875',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/931a70ae-90ee-448e-bedb-9d41f3eda647',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 28)},
#  {'id': 'b03fbc44-3d8e-4a6c-8a50-5ea3498568e0',
#   'subject': 'DY_010',
#   'start_time': '2020-01-27T11:15:18.176212',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/b03fbc44-3d8e-4a6c-8a50-5ea3498568e0',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 27)},
#  {'id': 'bb6a5aae-2431-401d-8f6a-9fdd6de655a9',
#   'subject': 'DY_010',
#   'start_time': '2020-01-24T14:20:24.754006',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/bb6a5aae-2431-401d-8f6a-9fdd6de655a9',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 24)},
#  {'id': '193fe7a8-4eb5-4f3e-815a-0c45864ddd77',
#   'subject': 'ZM_2240',
#   'start_time': '2020-01-24T09:57:45',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/193fe7a8-4eb5-4f3e-815a-0c45864ddd77',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 24)},
#  {'id': '510b1a50-825d-44ce-86f6-9678f5396e02',
#   'subject': 'ZM_2240',
#   'start_time': '2020-01-23T15:12:02',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/510b1a50-825d-44ce-86f6-9678f5396e02',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 23)},
#  {'id': '032ffcdf-7692-40b3-b9ff-8def1fc18b2e',
#   'subject': 'NYU-12',
#   'start_time': '2020-01-23T14:56:31',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/032ffcdf-7692-40b3-b9ff-8def1fc18b2e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 23)},
#  {'id': 'a8a8af78-16de-4841-ab07-fde4b5281a03',
#   'subject': 'NYU-12',
#   'start_time': '2020-01-22T15:39:54',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a8a8af78-16de-4841-ab07-fde4b5281a03',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 22)},
#  {'id': 'a8a8af78-16de-4841-ab07-fde4b5281a03',
#   'subject': 'NYU-12',
#   'start_time': '2020-01-22T15:39:54',
#   'number': 1,
#   'lab': 'angelakilab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/a8a8af78-16de-4841-ab07-fde4b5281a03',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 22)},
#  {'id': '2d5f6d81-38c4-4bdc-ac3c-302ea4d5f46e',
#   'subject': 'CSHL047',
#   'start_time': '2020-01-22T08:28:49',
#   'number': 2,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/2d5f6d81-38c4-4bdc-ac3c-302ea4d5f46e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 22)},
#  {'id': '4fa70097-8101-4f10-b585-db39429c5ed0',
#   'subject': 'DY_010',
#   'start_time': '2020-01-21T14:40:18.494392',
#   'number': 1,
#   'lab': 'danlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/4fa70097-8101-4f10-b585-db39429c5ed0',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 21)},
#  {'id': 'cb2ad999-a6cb-42ff-bf71-1774c57e5308',
#   'subject': 'ZM_2245',
#   'start_time': '2020-01-21T14:03:44',
#   'number': 2,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/cb2ad999-a6cb-42ff-bf71-1774c57e5308',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 21)},
#  {'id': 'b52182e7-39f6-4914-9717-136db589706e',
#   'subject': 'CSHL047',
#   'start_time': '2020-01-21T13:52:24',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/b52182e7-39f6-4914-9717-136db589706e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 21)},
#  {'id': 'b52182e7-39f6-4914-9717-136db589706e',
#   'subject': 'CSHL047',
#   'start_time': '2020-01-21T13:52:24',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/b52182e7-39f6-4914-9717-136db589706e',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 21)},
#  {'id': '89f0d6ff-69f4-45bc-b89e-72868abb042a',
#   'subject': 'CSHL047',
#   'start_time': '2020-01-20T14:56:51',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/89f0d6ff-69f4-45bc-b89e-72868abb042a',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 20)},
#  {'id': 'e9b57a5a-b06d-476d-ad20-7ec42a16f5f5',
#   'subject': 'CSH_ZAD_001',
#   'start_time': '2020-01-14T14:55:21.362694',
#   'number': 2,
#   'lab': 'zadorlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e9b57a5a-b06d-476d-ad20-7ec42a16f5f5',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 14)},
#  {'id': 'd839491f-55d8-4cbe-a298-7839208ba12b',
#   'subject': 'CSHL049',
#   'start_time': '2020-01-11T13:42:47',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/d839491f-55d8-4cbe-a298-7839208ba12b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 11)},
#  {'id': 'c99d53e6-c317-4c53-99ba-070b26673ac4',
#   'subject': 'CSHL049',
#   'start_time': '2020-01-09T15:43:57',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/c99d53e6-c317-4c53-99ba-070b26673ac4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 9)},
#  {'id': '4b7fbad4-f6de-43b4-9b15-c7c7ef44db4b',
#   'subject': 'CSHL049',
#   'start_time': '2020-01-08T15:52:42',
#   'number': 1,
#   'lab': 'churchlandlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/4b7fbad4-f6de-43b4-9b15-c7c7ef44db4b',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.5',
#   'date': datetime.date(2020, 1, 8)},
#  {'id': '614e1937-4b24-4ad3-9055-c8253d089919',
#   'subject': 'SWC_014',
#   'start_time': '2019-12-10T18:32:55',
#   'number': 1,
#   'lab': 'hoferlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/614e1937-4b24-4ad3-9055-c8253d089919',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.4',
#   'date': datetime.date(2019, 12, 10)},
#  {'id': 'aad23144-0e52-4eac-80c5-c4ee2decb198',
#   'subject': 'KS023',
#   'start_time': '2019-12-10T16:44:12.945000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/aad23144-0e52-4eac-80c5-c4ee2decb198',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 10)},
#  {'id': '15f742e1-1043-45c9-9504-f1e8a53c1744',
#   'subject': 'KS022',
#   'start_time': '2019-12-09T19:35:09.979000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/15f742e1-1043-45c9-9504-f1e8a53c1744',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 9)},
#  {'id': 'e5fae088-ed96-4d9b-82f9-dfd13c259d52',
#   'subject': 'ZM_1897',
#   'start_time': '2019-12-06T10:07:39',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/e5fae088-ed96-4d9b-82f9-dfd13c259d52',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.2.3',
#   'date': datetime.date(2019, 12, 6)},
#  {'id': '6cf2a88a-515b-4f7f-89a2-7d53eab9b5f4',
#   'subject': 'KS016',
#   'start_time': '2019-12-05T18:57:55.539000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6cf2a88a-515b-4f7f-89a2-7d53eab9b5f4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 5)},
#  {'id': '6cf2a88a-515b-4f7f-89a2-7d53eab9b5f4',
#   'subject': 'KS016',
#   'start_time': '2019-12-05T18:57:55.539000',
#   'number': 1,
#   'lab': 'cortexlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/6cf2a88a-515b-4f7f-89a2-7d53eab9b5f4',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 5)},
#  {'id': 'ebe090af-5922-4fcd-8fc6-17b8ba7bad6d',
#   'subject': 'ibl_witten_13',
#   'start_time': '2019-12-03T15:37:36',
#   'number': 1,
#   'lab': 'wittenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/ebe090af-5922-4fcd-8fc6-17b8ba7bad6d',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 3)},
#  {'id': 'dd4da095-4a99-4bf3-9727-f735077dba66',
#   'subject': 'ZM_1897',
#   'start_time': '2019-12-02T17:18:32',
#   'number': 1,
#   'lab': 'mainenlab',
#   'projects': ['ibl_neuropixel_brainwide_01'],
#   'url': 'https://openalyx.internationalbrainlab.org/sessions/dd4da095-4a99-4bf3-9727-f735077dba66',
#   'task_protocol': '_iblrig_tasks_ephysChoiceWorld6.1.3',
#   'date': datetime.date(2019, 12, 2)}]

# %%
#This is one way to wipe the data from the server, but it is difficuylt to implement, will need to be implemented before 
# running on the full 201 session but the 26 chosen should suffice for now.
    del sr
    if (session_id not in dont_wipe_these_sessions):
        session_path = str(one.eid2path(eid))
        del one
        # create the full path to the directory you want to delete
        # create the full path to the directory you want to delete
        dir_to_delete = f"{session_path}/raw_ephys_data"
        
        # call the bash command to remove the files
        remove_from_path_command = "find " + dir_to_delete + " -type d -exec rm -rf {} +"
        subprocess.run(remove_from_path_command, shell=True)
        
        # Then, remove the directory itself
        remove_dir_command = "find " + session_path + " -type d -name 'raw_ephys_data' -exec rm -r {} +"
        subprocess.run(remove_dir_command, shell=True)

# %%
one = ONE(password='international')
if (session_id not in dont_wipe_these_sessions):
    session_path = str(one.eid2path(eid))
    del one
    # create the full path to the directory you want to delete
    # create the full path to the directory you want to delete
    dir_to_delete = f"{session_path}/raw_ephys_data"
    
    # call the bash command to remove the files
    remove_from_path_command = "find " + dir_to_delete + " -type d -exec rm -rf {} +"
    subprocess.run(remove_from_path_command, shell=True)
    
    # Then, remove the directory itself
    remove_dir_command = "find " + session_path + " -type d -name 'raw_ephys_data' -exec rm -r {} +"
    subprocess.run(remove_dir_command, shell=True)
# Out:
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb9600000295’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb9600000295’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe01/.nfs00000000000cdb9600000295’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data/probe00/.nfs00000000000cd35600000296’: Device or resource busy

# %%
dir_to_delete
# Out:
# '/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA015/2022-03-31/001/raw_ephys_data'

# %%
if (session_id not in dont_wipe_these_sessions):
    session_path = str(one.eid2path(eid))
    # create the full path to the directory you want to delete
    dir_to_delete = f"{session_path}/raw_ephys_data"
    # create the new directory name
    dir_to_rename = f"{dir_to_delete}_delete_me"

    # rename the directory
    rename_command = f"mv {dir_to_delete} {dir_to_rename}"
    subprocess.run(rename_command, shell=True)

    # remove all files in the renamed directory
    remove_files_command = "find " + dir_to_rename + " -type f -exec rm -f {} +"
    subprocess.run(remove_files_command, shell=True)

    # remove the renamed directory itself
    remove_dir_command = "rm -r " + dir_to_rename
    subprocess.run(remove_dir_command, shell=True)
# Out:
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data_delete_me/probe00/.nfs00000000000cdb1800000286’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data_delete_me/probe01/.nfs00000000000cdb2400000287’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data_delete_me/probe00/.nfs00000000000cdb1800000286’: Device or resource busy
# rm: cannot remove ‘/space/scratch/IBL_data_cache/churchlandlab_ucla/Subjects/UCLA033/2022-02-15/001/raw_ephys_data_delete_me/probe01/.nfs00000000000cdb2400000287’: Device or resource busy

# %%
channels.allen2017_25um_acronym.shape
# Out:
# (384,)

# %%
np.unique(channels.allen2017_25um_acronym)
# Out:
# array(['CA1', 'DG-mo', 'DG-sg', 'MB', 'MRN', 'SCig', 'SCiw', 'VISp5',
#        'VISp6a', 'VISp6b', 'alv', 'bsc', 'fp', 'or', 'root'], dtype=object)

# %%
np.savez_compressed('/space/scratch/test_destripe_save/test_destripped_save.npz', arr=destriped)

# %%
sessions
# Out:
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
#
#            age_in_days sex                                  full_genotype  \
# id
# 715093703        118.0   M  Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...

# %%
sessions = cache.get_session_table()
sessions.head()
# Out:
#                    published_at  specimen_id           session_type  \
# id
# 715093703  2019-10-03T00:00:00Z    699733581  brain_observatory_1.1
# 719161530  2019-10-03T00:00:00Z    703279284  brain_observatory_1.1
# 721123822  2019-10-03T00:00:00Z    707296982  brain_observatory_1.1
# 732592105  2019-10-03T00:00:00Z    717038288  brain_observatory_1.1
# 737581020  2019-10-03T00:00:00Z    718643567  brain_observatory_1.1
#
#            age_in_days sex                                    full_genotype  \
# id
# 715093703        118.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 719161530        122.0   M    Sst-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 721123822        125.0   M  Pvalb-IRES-Cre/wt;Ai32(RCL-ChR2(H134R)_EYFP)/wt
# 732592105        100.0   M                                            wt/wt
# 737581020        108.0   M                                            wt/wt
#
#            unit_count  channel_count  probe_count  \
# id
# 715093703         884           2219            6
# 719161530         755           2214            6
# 721123822         444           2229            6
# 732592105         824           1847            5
# 737581020         568           2218            6
#
#                                   ecephys_structure_acronyms
# id
# 715093703  [CA1, VISrl, nan, PO, LP, LGd, CA3, DG, VISl, ...
# 719161530  [TH, Eth, APN, POL, LP, DG, CA1, VISpm, nan, N...
# 721123822  [MB, SCig, PPT, NOT, DG, CA1, VISam, nan, LP, ...
# 732592105       [grey, VISpm, nan, VISp, VISl, VISal, VISrl]
# 737581020      [grey, VISmma, nan, VISpm, VISp, VISl, VISrl]
